# %%
import numpy as np
import pandas as pd
import cvxpy as cp
from growth import *
from utils import *
from smoother import *
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from scipy.special import ndtri
import warnings

# %%
date_ref = pd.read_csv(f'data/CPRadmission/CA_HRR.csv', index_col=0)
date_ref.index = pd.to_datetime(date_ref.index, format='%Y-%m-%d')
date_seq = date_ref.index
len(date_seq)
warnings.filterwarnings('ignore')
cnt_thr = 20
trim_length = 20
gt_thr = 0.

ref_names = ['CPRadmission', 'JHUcase', 'CHNGclaim']
ref_dfs = [pd.read_csv(f'data/{data_name}/ALL_HRR.csv', index_col=0) for data_name in ref_names]
for d_idx in range(len(ref_names)):
    ref_dfs[d_idx].index = pd.to_datetime(ref_dfs[d_idx].index, format='%Y-%m-%d')
    ref_dfs[d_idx] = ref_dfs[d_idx].loc[date_seq]
    print(ref_names[d_idx], ref_dfs[d_idx].index[0], ref_dfs[d_idx].index[-1])
# Out:
# CPRadmission 2021-01-07 00:00:00 2022-06-21 00:00:00
# JHUcase 2021-01-07 00:00:00 2022-06-21 00:00:00
# CHNGclaim 2021-01-07 00:00:00 2022-06-21 00:00:00

# %%
noise_models = [['LogNormal', 'LogNormal', 'Poisson'], ['LogNormal', 'LogNormal', 'Poisson']]
penalty_values = [30, 100, 300, 1000, 3000, 10000, 30000]
zero_options = [['plus_one', 'plus_one', None], ['impute', 'impute', None]]
correction_indicators = [False, True, True]
consensus_nulls, consensus_alts, null_intervals, alt_intervals = construct_gt(ref_dfs, date_seq, trim_length, gt_thr, cnt_thr, penalty_values, noise_models, zero_options, correction_indicators, interval_threshold = 14)

# %%
import numpy as np

# number of intervals per key
counts = [len(v) for v in alt_intervals.values()]
avg_count = np.mean(counts)

# average length (in days) across all intervals
lengths = [
    (end - start).days
    for intervals in alt_intervals.values()
    for start, end in intervals
]
avg_length = np.mean(lengths)

print("Average count:", avg_count)
print("Average length (days):", avg_length)
# Out:
# Average count: 3.210526315789474
# Average length (days): 50.950819672131146

# %%
# window_sizes = [11, 21, 31]
window_sizes = range(5, 47, 2)
data_names = ['CPRadmission', 'JHUcase', 'CHNGclaim', 'doctorvisits', 'FBwtested', 'FBwhh', 'FBpositive', 'QUIDELpositive', 'FBwcli', 'GoogleS03', 'GoogleS04', 'GoogleS05']
meta_method = 'Stouffer'
meta_lists = [
    ['CPRadmission', 'JHUcase', 'CHNGclaim'],
    ['doctorvisits', 'GoogleS03', 'FBwtested', 'FBwhh', 'GoogleS05'],
    ['FBpositive', 'QUIDELpositive', 'FBwcli', 'GoogleS04'],
['CPRadmission', 'JHUcase', 'CHNGclaim', 'doctorvisits', 'FBwtested', 'FBwhh', 'FBpositive', 'QUIDELpositive', 'GoogleS03','GoogleS05'],
['CPRadmission', 'JHUcase', 'CHNGclaim', 'doctorvisits', 'FBwtested', 'FBwhh', 'FBpositive', 'QUIDELpositive', 'FBwcli', 'GoogleS03', 'GoogleS04', 'GoogleS05']
]

# build all the single‑element lists
singletons = [[elem] for group in meta_lists for elem in group]

# extend the original meta_lists
meta_lists += singletons

# %%
state = 'ALL'
real_dfs = [pd.read_csv(f'dataFU/{data_name}/{state}_HRR.csv', index_col=0) for data_name in data_names]
for d_idx in range(len(data_names)):
    real_dfs[d_idx].index = pd.to_datetime(real_dfs[d_idx].index, format='%Y-%m-%d')
    real_dfs[d_idx] = real_dfs[d_idx].loc[date_seq]
    print(data_names[d_idx], real_dfs[d_idx].index[0], real_dfs[d_idx].index[-1])
hrr_codes = [set(real_dfs[d_idx].columns) for d_idx in range(len(data_names))]
hrr_codes = set.intersection(*hrr_codes)
consensus_nulls_ = {hrr_code: consensus_nulls[hrr_code] for hrr_code in hrr_codes if hrr_code in consensus_nulls.keys()}
consensus_alts_ = {hrr_code: consensus_alts[hrr_code] for hrr_code in hrr_codes if hrr_code in consensus_alts.keys()}
alt_intervals_ = {hrr_code: alt_intervals[hrr_code] for hrr_code in hrr_codes if hrr_code in alt_intervals.keys()}
hrr_codes = list(sorted(consensus_nulls_.keys()))
# Out:
# CPRadmission 2021-01-07 00:00:00 2022-06-21 00:00:00
# JHUcase 2021-01-07 00:00:00 2022-06-21 00:00:00
# CHNGclaim 2021-01-07 00:00:00 2022-06-21 00:00:00
# doctorvisits 2021-01-07 00:00:00 2022-06-21 00:00:00
# FBwtested 2021-01-07 00:00:00 2022-06-21 00:00:00
# FBwhh 2021-01-07 00:00:00 2022-06-21 00:00:00
# FBpositive 2021-01-07 00:00:00 2022-06-21 00:00:00
# QUIDELpositive 2021-01-07 00:00:00 2022-06-21 00:00:00
# FBwcli 2021-01-07 00:00:00 2022-06-21 00:00:00
# GoogleS03 2021-01-07 00:00:00 2022-06-21 00:00:00
# GoogleS04 2021-01-07 00:00:00 2022-06-21 00:00:00
# GoogleS05 2021-01-07 00:00:00 2022-06-21 00:00:00

# %%
q = 0.95
cnt_thr = 0
max_delay_days = 60
outname = 'meta_full_3gt_84.txt'
print(f'alpha = {(1-q) * 100:.2f}%')
with open(outname, 'w') as f:
    print(f'alpha = {(1-q) * 100:.2f}%', file=f)
for window_size in window_sizes:
    print(f"Window size {window_size}")
    with open(outname, 'a') as f:
        print(f"Window size {window_size}", file=f)
    growth_rates_dfs = {}
    growth_pvals_dfs = {}
    for h_idx, hrr_df in enumerate(real_dfs):
        growth_rates_df = compute_growth_rates_df(hrr_df, date_seq, window_size, regression_model = 'LogLinear', zero_option = 'impute', end_days_plus = window_size//2, seq_thr = 0)
        null_dist, alt_dist = construct_gt_dist(hrr_df, growth_rates_df, cnt_thr, consensus_nulls_, consensus_alts_)
        growth_pvals_df = pd.DataFrame(index=growth_rates_df.index, columns=hrr_codes)
        for column in hrr_codes:
            for index in growth_rates_df.index:
                try:
                    growth_pvals_df.at[index, column] = np.mean(null_dist > growth_rates_df.at[index, column])
                except KeyError:
                    growth_pvals_df.at[index, column] = np.nan
        growth_rates_dfs[data_names[h_idx]] = growth_rates_df.copy()
        growth_pvals_dfs[data_names[h_idx]] = growth_pvals_df.copy()
        p_null_dist, p_alt_dist = construct_dist(growth_pvals_df, consensus_nulls_, consensus_alts_)
        pvals_threshold = np.quantile(p_null_dist, 1-q)
        delay_results = []
        for key, alt_interval in alt_intervals_.items():
            for start, end in alt_interval:
                interval_data = growth_pvals_df[key][start.strftime('%y-%m-%d'):end.strftime('%y-%m-%d')]
                exceeds_threshold = interval_data[interval_data < pvals_threshold]
                if not exceeds_threshold.empty:
                    first_exceedance_time = pd.to_datetime(exceeds_threshold.index[0], format='%y-%m-%d')
                    delay = (first_exceedance_time - start).days
                    delay_results.append(delay)
                else:
                    delay_results.append(max_delay_days)
        if len(delay_results) == 0:
            delay_days = max_delay_days
        else:
            delay_days = np.mean(delay_results)
        print(f'{data_names[h_idx]}, power = {np.mean(p_alt_dist < np.quantile(p_null_dist, 1-q))* 100:.2f}%, pthr = {pvals_threshold:.4f}, delay {delay_days:.4f} days')
        with open(outname, 'a') as f:
            print(f'{data_names[h_idx]}, power = {np.mean(p_alt_dist < np.quantile(p_null_dist, 1-q))* 100:.2f}%, pthr = {pvals_threshold:.4f}, delay {delay_days:.4f} days', file=f)

    for m_idx, meta_list in enumerate(meta_lists): 
        growth_pvals_df = pd.DataFrame(index=growth_rates_df.index, columns=hrr_codes)
        for column in hrr_codes:
            for index in growth_rates_df.index:
                pvals = np.array([growth_pvals_dfs[df_name].at[index, column] for df_name in meta_list])
                growth_pvals_df.at[index, column] = meta_pvals(pvals, meta_method)
        p_null_dist, p_alt_dist = construct_dist(growth_pvals_df, consensus_nulls_, consensus_alts_)
        pvals_threshold = np.quantile(p_null_dist, 1-q)
        delay_results = []
        for key, alt_interval in alt_intervals_.items():
            for start, end in alt_interval:
                interval_data = growth_pvals_df[key][start.strftime('%y-%m-%d'):end.strftime('%y-%m-%d')]
                exceeds_threshold = interval_data[interval_data < pvals_threshold]
                if not exceeds_threshold.empty:
                    first_exceedance_time = pd.to_datetime(exceeds_threshold.index[0], format='%y-%m-%d')
                    delay = (first_exceedance_time - start).days
                    delay_results.append(delay)
                else:
                    delay_results.append(max_delay_days)
        if len(delay_results) == 0:
            delay_days = max_delay_days
        else:
            delay_days = np.mean(delay_results)
        print(f'{m_idx}_{meta_method}, power = {np.mean(p_alt_dist < np.quantile(p_null_dist, 1-q))* 100:.2f}%, pthr = {pvals_threshold:.4f}, delay {delay_days:.4f} days')
        with open(outname, 'a') as f:
            print(f'{m_idx}_{meta_method}, power = {np.mean(p_alt_dist < np.quantile(p_null_dist, 1-q))* 100:.2f}%, pthr = {pvals_threshold:.4f}, delay {delay_days:.4f} days', file=f)

    for m_idx, meta_list in enumerate(meta_lists): 
        growth_cnts_df = pd.DataFrame(index=growth_rates_df.index, columns=hrr_codes)
        for column in hrr_codes:
            for i, index in enumerate(growth_rates_df.index):
                # growths = [growth_rates_dfs[df_name][column][i] for df_name in meta_list]
                growths = []
                for df_name in meta_list:
                    try:
                        growths.append(growth_rates_dfs[df_name][column][i])
                    except KeyError:
                        growths.append(0)
                growth_cnts_df.at[index, column] = np.sum((np.array(growths)>0))
        c_null_dist, c_alt_dist = construct_dist(growth_cnts_df, consensus_nulls_, consensus_alts_)
        cnts_threshold = np.quantile(c_null_dist, q)
        delay_results = []
        for key, alt_interval in alt_intervals_.items():
            for start, end in alt_interval:
                interval_data = growth_cnts_df[key][start.strftime('%y-%m-%d'):end.strftime('%y-%m-%d')]
                exceeds_threshold = interval_data[interval_data > cnts_threshold]
                if not exceeds_threshold.empty:
                    first_exceedance_time = pd.to_datetime(exceeds_threshold.index[0], format='%y-%m-%d')
                    delay = (first_exceedance_time - start).days
                    delay_results.append(delay)
                else:
                    delay_results.append(max_delay_days)
        if len(delay_results) == 0:
            delay_days = max_delay_days
        else:
            delay_days = np.mean(delay_results)
        print(f'{m_idx}_Stolerman, power = {np.mean(c_alt_dist > np.quantile(c_null_dist, q))* 100:.2f}%, cnt_thr = {cnts_threshold:.2f}, delay {delay_days:.4f} days')
        with open(outname, 'a') as f:
            print(f'{m_idx}_Stolerman, power = {np.mean(c_alt_dist > np.quantile(c_null_dist, q))* 100:.2f}%, cnt_thr = {cnts_threshold:.2f}, delay {delay_days:.4f} days', file=f)
# Out:
# alpha = 5.00%
# Window size 5
# CPRadmission, power = 54.56%, pthr = 0.0500, delay 3.9562 days
# JHUcase, power = 7.86%, pthr = 0.0542, delay 36.5421 days
# CHNGclaim, power = 10.74%, pthr = 0.0494, delay 15.0236 days
# doctorvisits, power = 19.42%, pthr = 0.0500, delay 11.2020 days
# FBwtested, power = 14.49%, pthr = 0.0500, delay 15.9865 days
# FBwhh, power = 8.33%, pthr = 0.0618, delay 25.0337 days
# FBpositive, power = 7.91%, pthr = 0.0747, delay 33.1313 days
# QUIDELpositive, power = 3.79%, pthr = 0.0602, delay 35.2862 days
# FBwcli, power = 4.94%, pthr = 0.0652, delay 29.8114 days
# GoogleS03, power = 12.44%, pthr = 0.0500, delay 12.2020 days
# GoogleS04, power = 7.18%, pthr = 0.0500, delay 19.2761 days
# GoogleS05, power = 6.49%, pthr = 0.0489, delay 27.1751 days
# 0_Stouffer, power = 40.92%, pthr = 0.1637, delay 3.2121 days
# 1_Stouffer, power = 24.02%, pthr = 0.2066, delay 6.7273 days
# 2_Stouffer, power = 8.95%, pthr = 0.2214, delay 19.9091 days
# 3_Stouffer, power = 42.71%, pthr = 0.2745, delay 3.6768 days
# 4_Stouffer, power = 36.15%, pthr = 0.2785, delay 4.0034 days
# 5_Stouffer, power = 54.54%, pthr = 0.0501, delay 3.9630 days
# 6_Stouffer, power = 7.84%, pthr = 0.0542, delay 36.5421 days
# 7_Stouffer, power = 10.73%, pthr = 0.0494, delay 15.0236 days
# 8_Stouffer, power = 19.43%, pthr = 0.0500, delay 11.2020 days
# 9_Stouffer, power = 12.47%, pthr = 0.0500, delay 12.2020 days
# 10_Stouffer, power = 14.55%, pthr = 0.0500, delay 15.8249 days
# 11_Stouffer, power = 8.32%, pthr = 0.0620, delay 25.0337 days
# 12_Stouffer, power = 6.49%, pthr = 0.0490, delay 27.1751 days
# 13_Stouffer, power = 7.91%, pthr = 0.0748, delay 33.1313 days
# 14_Stouffer, power = 3.79%, pthr = 0.0603, delay 35.2862 days
# 15_Stouffer, power = 4.94%, pthr = 0.0653, delay 29.8081 days
# 16_Stouffer, power = 7.19%, pthr = 0.0500, delay 19.2761 days
# 17_Stouffer, power = 54.54%, pthr = 0.0501, delay 3.9630 days
# 18_Stouffer, power = 7.84%, pthr = 0.0542, delay 36.5421 days
# 19_Stouffer, power = 10.73%, pthr = 0.0494, delay 15.0236 days
# 20_Stouffer, power = 19.43%, pthr = 0.0500, delay 11.2020 days
# 21_Stouffer, power = 14.55%, pthr = 0.0500, delay 15.8249 days
# 22_Stouffer, power = 8.32%, pthr = 0.0620, delay 25.0337 days
# 23_Stouffer, power = 7.91%, pthr = 0.0748, delay 33.1313 days
# 24_Stouffer, power = 3.79%, pthr = 0.0603, delay 35.2862 days
# 25_Stouffer, power = 12.47%, pthr = 0.0500, delay 12.2020 days
# 26_Stouffer, power = 6.49%, pthr = 0.0490, delay 27.1751 days
# 27_Stouffer, power = 54.54%, pthr = 0.0501, delay 3.9630 days
# 28_Stouffer, power = 7.84%, pthr = 0.0542, delay 36.5421 days
# 29_Stouffer, power = 10.73%, pthr = 0.0494, delay 15.0236 days
# 30_Stouffer, power = 19.43%, pthr = 0.0500, delay 11.2020 days
# 31_Stouffer, power = 14.55%, pthr = 0.0500, delay 15.8249 days
# 32_Stouffer, power = 8.32%, pthr = 0.0620, delay 25.0337 days
# 33_Stouffer, power = 7.91%, pthr = 0.0748, delay 33.1313 days
# 34_Stouffer, power = 3.79%, pthr = 0.0603, delay 35.2862 days
# 35_Stouffer, power = 4.94%, pthr = 0.0653, delay 29.8081 days
# 36_Stouffer, power = 12.47%, pthr = 0.0500, delay 12.2020 days
# 37_Stouffer, power = 7.19%, pthr = 0.0500, delay 19.2761 days
# 38_Stouffer, power = 6.49%, pthr = 0.0490, delay 27.1751 days
# 0_Stolerman, power = 32.63%, cnt_thr = 2.00, delay 5.3737 days
# 1_Stolerman, power = 7.88%, cnt_thr = 4.00, delay 26.9226 days
# 2_Stolerman, power = 5.82%, cnt_thr = 3.00, delay 35.2391 days
# 3_Stolerman, power = 16.98%, cnt_thr = 7.00, delay 18.2155 days
# 4_Stolerman, power = 20.53%, cnt_thr = 8.00, delay 15.3939 days
# 5_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 6_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 7_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 8_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 9_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 10_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 11_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 12_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 13_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 14_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 15_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 16_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 17_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 18_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 19_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 20_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 21_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 22_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 23_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 24_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 25_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 26_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 27_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 28_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 29_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 30_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 31_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 32_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 33_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 34_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 35_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 36_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 37_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 38_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# Window size 7
# CPRadmission, power = 67.11%, pthr = 0.0500, delay 3.7172 days
# JHUcase, power = 11.01%, pthr = 0.0531, delay 27.2795 days
# CHNGclaim, power = 17.21%, pthr = 0.0491, delay 12.1010 days
# doctorvisits, power = 24.48%, pthr = 0.0500, delay 11.7811 days
# FBwtested, power = 17.57%, pthr = 0.0500, delay 17.1212 days
# FBwhh, power = 10.19%, pthr = 0.0567, delay 24.8754 days
# FBpositive, power = 9.08%, pthr = 0.0723, delay 33.5758 days
# QUIDELpositive, power = 4.66%, pthr = 0.0557, delay 33.2525 days
# FBwcli, power = 5.34%, pthr = 0.0619, delay 29.8586 days
# GoogleS03, power = 17.45%, pthr = 0.0500, delay 10.4377 days
# GoogleS04, power = 9.67%, pthr = 0.0500, delay 18.1549 days
# GoogleS05, power = 8.51%, pthr = 0.0489, delay 25.8519 days
# 0_Stouffer, power = 60.75%, pthr = 0.1648, delay 2.3906 days
# 1_Stouffer, power = 33.65%, pthr = 0.2011, delay 5.5960 days
# 2_Stouffer, power = 12.53%, pthr = 0.2128, delay 17.1212 days
# 3_Stouffer, power = 59.08%, pthr = 0.2663, delay 2.6061 days
# 4_Stouffer, power = 51.55%, pthr = 0.2721, delay 2.9192 days
# 5_Stouffer, power = 67.02%, pthr = 0.0501, delay 3.7374 days
# 6_Stouffer, power = 10.95%, pthr = 0.0532, delay 27.2795 days
# 7_Stouffer, power = 17.25%, pthr = 0.0492, delay 12.0976 days
# 8_Stouffer, power = 24.50%, pthr = 0.0500, delay 11.6195 days
# 9_Stouffer, power = 17.45%, pthr = 0.0500, delay 10.4007 days
# 10_Stouffer, power = 17.59%, pthr = 0.0500, delay 17.1212 days
# 11_Stouffer, power = 10.19%, pthr = 0.0567, delay 24.8754 days
# 12_Stouffer, power = 8.50%, pthr = 0.0489, delay 25.8519 days
# 13_Stouffer, power = 9.09%, pthr = 0.0726, delay 33.5758 days
# 14_Stouffer, power = 4.66%, pthr = 0.0558, delay 33.2525 days
# 15_Stouffer, power = 5.34%, pthr = 0.0620, delay 29.8586 days
# 16_Stouffer, power = 9.63%, pthr = 0.0500, delay 18.1582 days
# 17_Stouffer, power = 67.02%, pthr = 0.0501, delay 3.7374 days
# 18_Stouffer, power = 10.95%, pthr = 0.0532, delay 27.2795 days
# 19_Stouffer, power = 17.25%, pthr = 0.0492, delay 12.0976 days
# 20_Stouffer, power = 24.50%, pthr = 0.0500, delay 11.6195 days
# 21_Stouffer, power = 17.59%, pthr = 0.0500, delay 17.1212 days
# 22_Stouffer, power = 10.19%, pthr = 0.0567, delay 24.8754 days
# 23_Stouffer, power = 9.09%, pthr = 0.0726, delay 33.5758 days
# 24_Stouffer, power = 4.66%, pthr = 0.0558, delay 33.2525 days
# 25_Stouffer, power = 17.45%, pthr = 0.0500, delay 10.4007 days
# 26_Stouffer, power = 8.50%, pthr = 0.0489, delay 25.8519 days
# 27_Stouffer, power = 67.02%, pthr = 0.0501, delay 3.7374 days
# 28_Stouffer, power = 10.95%, pthr = 0.0532, delay 27.2795 days
# 29_Stouffer, power = 17.25%, pthr = 0.0492, delay 12.0976 days
# 30_Stouffer, power = 24.50%, pthr = 0.0500, delay 11.6195 days
# 31_Stouffer, power = 17.59%, pthr = 0.0500, delay 17.1212 days
# 32_Stouffer, power = 10.19%, pthr = 0.0567, delay 24.8754 days
# 33_Stouffer, power = 9.09%, pthr = 0.0726, delay 33.5758 days
# 34_Stouffer, power = 4.66%, pthr = 0.0558, delay 33.2525 days
# 35_Stouffer, power = 5.34%, pthr = 0.0620, delay 29.8586 days
# 36_Stouffer, power = 17.45%, pthr = 0.0500, delay 10.4007 days
# 37_Stouffer, power = 9.63%, pthr = 0.0500, delay 18.1582 days
# 38_Stouffer, power = 8.50%, pthr = 0.0489, delay 25.8519 days
# 0_Stolerman, power = 41.18%, cnt_thr = 2.00, delay 4.8451 days
# 1_Stolerman, power = 10.94%, cnt_thr = 4.00, delay 25.9731 days
# 2_Stolerman, power = 7.72%, cnt_thr = 3.00, delay 33.7071 days
# 3_Stolerman, power = 43.23%, cnt_thr = 6.00, delay 6.0505 days
# 4_Stolerman, power = 27.03%, cnt_thr = 8.00, delay 12.9091 days
# 5_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 6_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 7_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 8_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 9_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 10_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 11_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 12_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 13_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 14_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 15_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 16_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 17_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 18_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 19_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 20_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 21_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 22_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 23_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 24_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 25_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 26_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 27_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 28_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 29_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 30_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 31_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 32_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 33_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 34_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 35_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 36_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 37_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 38_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# Window size 9
# CPRadmission, power = 77.01%, pthr = 0.0500, delay 3.2929 days
# JHUcase, power = 24.37%, pthr = 0.0508, delay 12.0135 days
# CHNGclaim, power = 28.42%, pthr = 0.0482, delay 7.7239 days
# doctorvisits, power = 30.00%, pthr = 0.0500, delay 12.1279 days
# FBwtested, power = 20.62%, pthr = 0.0500, delay 16.5556 days
# FBwhh, power = 14.40%, pthr = 0.0531, delay 24.4276 days
# FBpositive, power = 10.39%, pthr = 0.0692, delay 34.1448 days
# QUIDELpositive, power = 6.05%, pthr = 0.0494, delay 32.4848 days
# FBwcli, power = 6.29%, pthr = 0.0572, delay 30.0606 days
# GoogleS03, power = 23.12%, pthr = 0.0500, delay 10.4242 days
# GoogleS04, power = 15.54%, pthr = 0.0500, delay 13.9663 days
# GoogleS05, power = 11.57%, pthr = 0.0485, delay 21.2525 days
# 0_Stouffer, power = 81.54%, pthr = 0.1621, delay 1.3030 days
# 1_Stouffer, power = 41.57%, pthr = 0.1896, delay 5.8485 days
# 2_Stouffer, power = 16.76%, pthr = 0.1936, delay 16.2694 days
# 3_Stouffer, power = 74.03%, pthr = 0.2517, delay 1.8114 days
# 4_Stouffer, power = 69.26%, pthr = 0.2648, delay 2.0168 days
# 5_Stouffer, power = 76.88%, pthr = 0.0501, delay 3.3367 days
# 6_Stouffer, power = 24.33%, pthr = 0.0508, delay 11.9596 days
# 7_Stouffer, power = 28.39%, pthr = 0.0483, delay 7.7273 days
# 8_Stouffer, power = 30.00%, pthr = 0.0500, delay 12.1279 days
# 9_Stouffer, power = 23.13%, pthr = 0.0500, delay 10.4242 days
# 10_Stouffer, power = 20.62%, pthr = 0.0500, delay 16.5556 days
# 11_Stouffer, power = 14.42%, pthr = 0.0533, delay 24.4276 days
# 12_Stouffer, power = 11.55%, pthr = 0.0486, delay 21.0909 days
# 13_Stouffer, power = 10.40%, pthr = 0.0693, delay 34.1448 days
# 14_Stouffer, power = 6.06%, pthr = 0.0496, delay 32.4815 days
# 15_Stouffer, power = 6.27%, pthr = 0.0575, delay 30.0606 days
# 16_Stouffer, power = 15.37%, pthr = 0.0500, delay 13.9731 days
# 17_Stouffer, power = 76.88%, pthr = 0.0501, delay 3.3367 days
# 18_Stouffer, power = 24.33%, pthr = 0.0508, delay 11.9596 days
# 19_Stouffer, power = 28.39%, pthr = 0.0483, delay 7.7273 days
# 20_Stouffer, power = 30.00%, pthr = 0.0500, delay 12.1279 days
# 21_Stouffer, power = 20.62%, pthr = 0.0500, delay 16.5556 days
# 22_Stouffer, power = 14.42%, pthr = 0.0533, delay 24.4276 days
# 23_Stouffer, power = 10.40%, pthr = 0.0693, delay 34.1448 days
# 24_Stouffer, power = 6.06%, pthr = 0.0496, delay 32.4815 days
# 25_Stouffer, power = 23.13%, pthr = 0.0500, delay 10.4242 days
# 26_Stouffer, power = 11.55%, pthr = 0.0486, delay 21.0909 days
# 27_Stouffer, power = 76.88%, pthr = 0.0501, delay 3.3367 days
# 28_Stouffer, power = 24.33%, pthr = 0.0508, delay 11.9596 days
# 29_Stouffer, power = 28.39%, pthr = 0.0483, delay 7.7273 days
# 30_Stouffer, power = 30.00%, pthr = 0.0500, delay 12.1279 days
# 31_Stouffer, power = 20.62%, pthr = 0.0500, delay 16.5556 days
# 32_Stouffer, power = 14.42%, pthr = 0.0533, delay 24.4276 days
# 33_Stouffer, power = 10.40%, pthr = 0.0693, delay 34.1448 days
# 34_Stouffer, power = 6.06%, pthr = 0.0496, delay 32.4815 days
# 35_Stouffer, power = 6.27%, pthr = 0.0575, delay 30.0606 days
# 36_Stouffer, power = 23.13%, pthr = 0.0500, delay 10.4242 days
# 37_Stouffer, power = 15.37%, pthr = 0.0500, delay 13.9731 days
# 38_Stouffer, power = 11.55%, pthr = 0.0486, delay 21.0909 days
# 0_Stolerman, power = 52.87%, cnt_thr = 2.00, delay 4.3131 days
# 1_Stolerman, power = 14.72%, cnt_thr = 4.00, delay 25.0774 days
# 2_Stolerman, power = 10.36%, cnt_thr = 3.00, delay 32.5219 days
# 3_Stolerman, power = 51.57%, cnt_thr = 6.00, delay 5.1077 days
# 4_Stolerman, power = 52.31%, cnt_thr = 7.00, delay 5.2727 days
# 5_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 6_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 7_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 8_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 9_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 10_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 11_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 12_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 13_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 14_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 15_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 16_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 17_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 18_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 19_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 20_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 21_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 22_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 23_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 24_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 25_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 26_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 27_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 28_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 29_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 30_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 31_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 32_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 33_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 34_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 35_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 36_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 37_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 38_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# Window size 11
# CPRadmission, power = 83.32%, pthr = 0.0500, delay 2.8148 days
# JHUcase, power = 37.74%, pthr = 0.0518, delay 5.9596 days
# CHNGclaim, power = 42.20%, pthr = 0.0477, delay 5.0808 days
# doctorvisits, power = 34.81%, pthr = 0.0500, delay 10.9630 days
# FBwtested, power = 24.49%, pthr = 0.0500, delay 16.9764 days
# FBwhh, power = 18.10%, pthr = 0.0488, delay 23.9125 days
# FBpositive, power = 11.55%, pthr = 0.0660, delay 34.1111 days
# QUIDELpositive, power = 7.19%, pthr = 0.0463, delay 32.2727 days
# FBwcli, power = 7.46%, pthr = 0.0554, delay 30.0438 days
# GoogleS03, power = 26.98%, pthr = 0.0500, delay 11.0236 days
# GoogleS04, power = 16.82%, pthr = 0.0500, delay 14.6835 days
# GoogleS05, power = 15.93%, pthr = 0.0486, delay 18.4040 days
# 0_Stouffer, power = 89.40%, pthr = 0.1538, delay 0.7542 days
# 1_Stouffer, power = 49.48%, pthr = 0.1847, delay 5.3300 days
# 2_Stouffer, power = 20.25%, pthr = 0.1865, delay 14.3603 days
# 3_Stouffer, power = 82.32%, pthr = 0.2405, delay 1.2997 days
# 4_Stouffer, power = 78.43%, pthr = 0.2541, delay 1.4714 days
# 5_Stouffer, power = 83.28%, pthr = 0.0501, delay 2.8249 days
# 6_Stouffer, power = 37.54%, pthr = 0.0518, delay 5.9663 days
# 7_Stouffer, power = 42.18%, pthr = 0.0477, delay 5.0842 days
# 8_Stouffer, power = 34.82%, pthr = 0.0500, delay 10.9630 days
# 9_Stouffer, power = 27.01%, pthr = 0.0500, delay 11.0236 days
# 10_Stouffer, power = 24.51%, pthr = 0.0500, delay 16.9697 days
# 11_Stouffer, power = 18.10%, pthr = 0.0490, delay 23.9091 days
# 12_Stouffer, power = 15.89%, pthr = 0.0486, delay 18.4040 days
# 13_Stouffer, power = 11.62%, pthr = 0.0663, delay 34.0303 days
# 14_Stouffer, power = 7.23%, pthr = 0.0464, delay 32.2660 days
# 15_Stouffer, power = 7.45%, pthr = 0.0557, delay 30.0034 days
# 16_Stouffer, power = 16.72%, pthr = 0.0500, delay 14.5690 days
# 17_Stouffer, power = 83.28%, pthr = 0.0501, delay 2.8249 days
# 18_Stouffer, power = 37.54%, pthr = 0.0518, delay 5.9663 days
# 19_Stouffer, power = 42.18%, pthr = 0.0477, delay 5.0842 days
# 20_Stouffer, power = 34.82%, pthr = 0.0500, delay 10.9630 days
# 21_Stouffer, power = 24.51%, pthr = 0.0500, delay 16.9697 days
# 22_Stouffer, power = 18.10%, pthr = 0.0490, delay 23.9091 days
# 23_Stouffer, power = 11.62%, pthr = 0.0663, delay 34.0303 days
# 24_Stouffer, power = 7.23%, pthr = 0.0464, delay 32.2660 days
# 25_Stouffer, power = 27.01%, pthr = 0.0500, delay 11.0236 days
# 26_Stouffer, power = 15.89%, pthr = 0.0486, delay 18.4040 days
# 27_Stouffer, power = 83.28%, pthr = 0.0501, delay 2.8249 days
# 28_Stouffer, power = 37.54%, pthr = 0.0518, delay 5.9663 days
# 29_Stouffer, power = 42.18%, pthr = 0.0477, delay 5.0842 days
# 30_Stouffer, power = 34.82%, pthr = 0.0500, delay 10.9630 days
# 31_Stouffer, power = 24.51%, pthr = 0.0500, delay 16.9697 days
# 32_Stouffer, power = 18.10%, pthr = 0.0490, delay 23.9091 days
# 33_Stouffer, power = 11.62%, pthr = 0.0663, delay 34.0303 days
# 34_Stouffer, power = 7.23%, pthr = 0.0464, delay 32.2660 days
# 35_Stouffer, power = 7.45%, pthr = 0.0557, delay 30.0034 days
# 36_Stouffer, power = 27.01%, pthr = 0.0500, delay 11.0236 days
# 37_Stouffer, power = 16.72%, pthr = 0.0500, delay 14.5690 days
# 38_Stouffer, power = 15.89%, pthr = 0.0486, delay 18.4040 days
# 0_Stolerman, power = 59.25%, cnt_thr = 2.00, delay 3.9798 days
# 1_Stolerman, power = 17.75%, cnt_thr = 4.00, delay 24.4209 days
# 2_Stolerman, power = 12.19%, cnt_thr = 3.00, delay 32.0943 days
# 3_Stolerman, power = 57.09%, cnt_thr = 6.00, delay 5.1044 days
# 4_Stolerman, power = 57.63%, cnt_thr = 7.00, delay 5.4007 days
# 5_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 6_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 7_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 8_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 9_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 10_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 11_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 12_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 13_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 14_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 15_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 16_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 17_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 18_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 19_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 20_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 21_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 22_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 23_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 24_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 25_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 26_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 27_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 28_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 29_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 30_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 31_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 32_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 33_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 34_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 35_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 36_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 37_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 38_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# Window size 13
# CPRadmission, power = 87.50%, pthr = 0.0500, delay 2.4141 days
# JHUcase, power = 36.39%, pthr = 0.0525, delay 6.8215 days
# CHNGclaim, power = 54.40%, pthr = 0.0478, delay 3.8687 days
# doctorvisits, power = 38.69%, pthr = 0.0500, delay 10.6532 days
# FBwtested, power = 28.30%, pthr = 0.0500, delay 17.9024 days
# FBwhh, power = 22.40%, pthr = 0.0449, delay 23.5185 days
# FBpositive, power = 12.90%, pthr = 0.0642, delay 34.1886 days
# QUIDELpositive, power = 8.86%, pthr = 0.0414, delay 32.1380 days
# FBwcli, power = 8.63%, pthr = 0.0516, delay 29.7778 days
# GoogleS03, power = 28.71%, pthr = 0.0500, delay 9.4377 days
# GoogleS04, power = 15.87%, pthr = 0.0500, delay 15.8889 days
# GoogleS05, power = 20.83%, pthr = 0.0489, delay 17.6027 days
# 0_Stouffer, power = 91.70%, pthr = 0.1506, delay 0.6700 days
# 1_Stouffer, power = 55.87%, pthr = 0.1787, delay 5.0202 days
# 2_Stouffer, power = 22.18%, pthr = 0.1811, delay 13.6162 days
# 3_Stouffer, power = 86.24%, pthr = 0.2294, delay 1.1279 days
# 4_Stouffer, power = 81.33%, pthr = 0.2414, delay 1.3939 days
# 5_Stouffer, power = 87.44%, pthr = 0.0501, delay 2.4478 days
# 6_Stouffer, power = 36.25%, pthr = 0.0526, delay 6.7374 days
# 7_Stouffer, power = 54.43%, pthr = 0.0478, delay 3.8721 days
# 8_Stouffer, power = 38.73%, pthr = 0.0500, delay 10.5791 days
# 9_Stouffer, power = 28.72%, pthr = 0.0500, delay 9.4377 days
# 10_Stouffer, power = 28.26%, pthr = 0.0500, delay 17.9024 days
# 11_Stouffer, power = 22.42%, pthr = 0.0451, delay 23.5185 days
# 12_Stouffer, power = 20.80%, pthr = 0.0489, delay 17.6027 days
# 13_Stouffer, power = 12.93%, pthr = 0.0647, delay 34.1279 days
# 14_Stouffer, power = 8.89%, pthr = 0.0415, delay 32.0370 days
# 15_Stouffer, power = 8.62%, pthr = 0.0518, delay 29.7744 days
# 16_Stouffer, power = 15.82%, pthr = 0.0500, delay 15.8889 days
# 17_Stouffer, power = 87.44%, pthr = 0.0501, delay 2.4478 days
# 18_Stouffer, power = 36.25%, pthr = 0.0526, delay 6.7374 days
# 19_Stouffer, power = 54.43%, pthr = 0.0478, delay 3.8721 days
# 20_Stouffer, power = 38.73%, pthr = 0.0500, delay 10.5791 days
# 21_Stouffer, power = 28.26%, pthr = 0.0500, delay 17.9024 days
# 22_Stouffer, power = 22.42%, pthr = 0.0451, delay 23.5185 days
# 23_Stouffer, power = 12.93%, pthr = 0.0647, delay 34.1279 days
# 24_Stouffer, power = 8.89%, pthr = 0.0415, delay 32.0370 days
# 25_Stouffer, power = 28.72%, pthr = 0.0500, delay 9.4377 days
# 26_Stouffer, power = 20.80%, pthr = 0.0489, delay 17.6027 days
# 27_Stouffer, power = 87.44%, pthr = 0.0501, delay 2.4478 days
# 28_Stouffer, power = 36.25%, pthr = 0.0526, delay 6.7374 days
# 29_Stouffer, power = 54.43%, pthr = 0.0478, delay 3.8721 days
# 30_Stouffer, power = 38.73%, pthr = 0.0500, delay 10.5791 days
# 31_Stouffer, power = 28.26%, pthr = 0.0500, delay 17.9024 days
# 32_Stouffer, power = 22.42%, pthr = 0.0451, delay 23.5185 days
# 33_Stouffer, power = 12.93%, pthr = 0.0647, delay 34.1279 days
# 34_Stouffer, power = 8.89%, pthr = 0.0415, delay 32.0370 days
# 35_Stouffer, power = 8.62%, pthr = 0.0518, delay 29.7744 days
# 36_Stouffer, power = 28.72%, pthr = 0.0500, delay 9.4377 days
# 37_Stouffer, power = 15.82%, pthr = 0.0500, delay 15.8889 days
# 38_Stouffer, power = 20.80%, pthr = 0.0489, delay 17.6027 days
# 0_Stolerman, power = 62.92%, cnt_thr = 2.00, delay 3.9293 days
# 1_Stolerman, power = 19.91%, cnt_thr = 4.00, delay 24.7643 days
# 2_Stolerman, power = 13.02%, cnt_thr = 3.00, delay 31.9966 days
# 3_Stolerman, power = 61.19%, cnt_thr = 6.00, delay 4.7205 days
# 4_Stolerman, power = 61.09%, cnt_thr = 7.00, delay 4.8047 days
# 5_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 6_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 7_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 8_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 9_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 10_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 11_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 12_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 13_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 14_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 15_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 16_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 17_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 18_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 19_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 20_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 21_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 22_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 23_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 24_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 25_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 26_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 27_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 28_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 29_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 30_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 31_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 32_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 33_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 34_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 35_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 36_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 37_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 38_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# Window size 15
# CPRadmission, power = 90.84%, pthr = 0.0500, delay 2.1010 days
# JHUcase, power = 53.80%, pthr = 0.0512, delay 3.4714 days
# CHNGclaim, power = 67.01%, pthr = 0.0478, delay 2.8822 days
# doctorvisits, power = 43.29%, pthr = 0.0500, delay 9.9125 days
# FBwtested, power = 33.17%, pthr = 0.0500, delay 17.1684 days
# FBwhh, power = 26.29%, pthr = 0.0412, delay 22.9394 days
# FBpositive, power = 14.55%, pthr = 0.0610, delay 34.2593 days
# QUIDELpositive, power = 10.34%, pthr = 0.0384, delay 31.6902 days
# FBwcli, power = 9.34%, pthr = 0.0493, delay 30.9865 days
# GoogleS03, power = 32.01%, pthr = 0.0500, delay 9.3805 days
# GoogleS04, power = 19.89%, pthr = 0.0500, delay 15.5724 days
# GoogleS05, power = 25.83%, pthr = 0.0489, delay 16.1785 days
# 0_Stouffer, power = 95.47%, pthr = 0.1422, delay 0.3737 days
# 1_Stouffer, power = 62.31%, pthr = 0.1735, delay 4.6465 days
# 2_Stouffer, power = 25.18%, pthr = 0.1687, delay 13.5118 days
# 3_Stouffer, power = 90.51%, pthr = 0.2167, delay 0.9428 days
# 4_Stouffer, power = 86.79%, pthr = 0.2302, delay 1.0370 days
# 5_Stouffer, power = 90.47%, pthr = 0.0501, delay 2.1953 days
# 6_Stouffer, power = 53.71%, pthr = 0.0513, delay 3.4714 days
# 7_Stouffer, power = 67.05%, pthr = 0.0478, delay 2.8889 days
# 8_Stouffer, power = 43.30%, pthr = 0.0500, delay 9.9125 days
# 9_Stouffer, power = 32.06%, pthr = 0.0500, delay 9.3434 days
# 10_Stouffer, power = 33.16%, pthr = 0.0500, delay 17.1515 days
# 11_Stouffer, power = 26.38%, pthr = 0.0413, delay 22.9259 days
# 12_Stouffer, power = 25.80%, pthr = 0.0490, delay 16.1785 days
# 13_Stouffer, power = 14.57%, pthr = 0.0614, delay 34.2525 days
# 14_Stouffer, power = 10.34%, pthr = 0.0384, delay 31.6902 days
# 15_Stouffer, power = 9.43%, pthr = 0.0495, delay 30.9697 days
# 16_Stouffer, power = 19.87%, pthr = 0.0500, delay 15.5623 days
# 17_Stouffer, power = 90.47%, pthr = 0.0501, delay 2.1953 days
# 18_Stouffer, power = 53.71%, pthr = 0.0513, delay 3.4714 days
# 19_Stouffer, power = 67.05%, pthr = 0.0478, delay 2.8889 days
# 20_Stouffer, power = 43.30%, pthr = 0.0500, delay 9.9125 days
# 21_Stouffer, power = 33.16%, pthr = 0.0500, delay 17.1515 days
# 22_Stouffer, power = 26.38%, pthr = 0.0413, delay 22.9259 days
# 23_Stouffer, power = 14.57%, pthr = 0.0614, delay 34.2525 days
# 24_Stouffer, power = 10.34%, pthr = 0.0384, delay 31.6902 days
# 25_Stouffer, power = 32.06%, pthr = 0.0500, delay 9.3434 days
# 26_Stouffer, power = 25.80%, pthr = 0.0490, delay 16.1785 days
# 27_Stouffer, power = 90.47%, pthr = 0.0501, delay 2.1953 days
# 28_Stouffer, power = 53.71%, pthr = 0.0513, delay 3.4714 days
# 29_Stouffer, power = 67.05%, pthr = 0.0478, delay 2.8889 days
# 30_Stouffer, power = 43.30%, pthr = 0.0500, delay 9.9125 days
# 31_Stouffer, power = 33.16%, pthr = 0.0500, delay 17.1515 days
# 32_Stouffer, power = 26.38%, pthr = 0.0413, delay 22.9259 days
# 33_Stouffer, power = 14.57%, pthr = 0.0614, delay 34.2525 days
# 34_Stouffer, power = 10.34%, pthr = 0.0384, delay 31.6902 days
# 35_Stouffer, power = 9.43%, pthr = 0.0495, delay 30.9697 days
# 36_Stouffer, power = 32.06%, pthr = 0.0500, delay 9.3434 days
# 37_Stouffer, power = 19.87%, pthr = 0.0500, delay 15.5623 days
# 38_Stouffer, power = 25.80%, pthr = 0.0490, delay 16.1785 days
# 0_Stolerman, power = 94.53%, cnt_thr = 1.00, delay 0.4680 days
# 1_Stolerman, power = 53.10%, cnt_thr = 3.00, delay 5.9495 days
# 2_Stolerman, power = 14.99%, cnt_thr = 3.00, delay 31.0505 days
# 3_Stolerman, power = 83.16%, cnt_thr = 5.00, delay 1.5993 days
# 4_Stolerman, power = 66.04%, cnt_thr = 7.00, delay 4.0236 days
# 5_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 6_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 7_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 8_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 9_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 10_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 11_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 12_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 13_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 14_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 15_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 16_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 17_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 18_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 19_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 20_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 21_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 22_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 23_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 24_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 25_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 26_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 27_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 28_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 29_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 30_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 31_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 32_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 33_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 34_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 35_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 36_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 37_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 38_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# Window size 17
# CPRadmission, power = 93.19%, pthr = 0.0500, delay 1.7980 days
# JHUcase, power = 77.20%, pthr = 0.0484, delay 0.8350 days
# CHNGclaim, power = 77.55%, pthr = 0.0478, delay 2.4545 days
# doctorvisits, power = 47.77%, pthr = 0.0500, delay 9.6768 days
# FBwtested, power = 37.29%, pthr = 0.0500, delay 16.7542 days
# FBwhh, power = 29.89%, pthr = 0.0376, delay 22.7407 days
# FBpositive, power = 16.18%, pthr = 0.0589, delay 33.6498 days
# QUIDELpositive, power = 11.66%, pthr = 0.0353, delay 30.8182 days
# FBwcli, power = 10.70%, pthr = 0.0449, delay 30.7643 days
# GoogleS03, power = 35.78%, pthr = 0.0500, delay 10.6128 days
# GoogleS04, power = 25.66%, pthr = 0.0500, delay 17.9495 days
# GoogleS05, power = 30.04%, pthr = 0.0485, delay 14.9259 days
# 0_Stouffer, power = 97.57%, pthr = 0.1297, delay 0.2424 days
# 1_Stouffer, power = 67.32%, pthr = 0.1655, delay 4.2189 days
# 2_Stouffer, power = 29.77%, pthr = 0.1600, delay 14.0943 days
# 3_Stouffer, power = 93.83%, pthr = 0.2064, delay 0.5724 days
# 4_Stouffer, power = 90.96%, pthr = 0.2205, delay 0.6869 days
# 5_Stouffer, power = 92.31%, pthr = 0.0501, delay 1.9798 days
# 6_Stouffer, power = 77.12%, pthr = 0.0485, delay 0.8316 days
# 7_Stouffer, power = 77.59%, pthr = 0.0478, delay 2.4579 days
# 8_Stouffer, power = 47.79%, pthr = 0.0500, delay 9.6734 days
# 9_Stouffer, power = 35.78%, pthr = 0.0500, delay 10.6128 days
# 10_Stouffer, power = 37.20%, pthr = 0.0500, delay 16.7104 days
# 11_Stouffer, power = 29.91%, pthr = 0.0377, delay 22.7374 days
# 12_Stouffer, power = 29.98%, pthr = 0.0486, delay 14.9226 days
# 13_Stouffer, power = 16.23%, pthr = 0.0595, delay 33.6364 days
# 14_Stouffer, power = 11.67%, pthr = 0.0355, delay 30.8182 days
# 15_Stouffer, power = 10.72%, pthr = 0.0450, delay 30.5993 days
# 16_Stouffer, power = 24.91%, pthr = 0.0500, delay 17.9495 days
# 17_Stouffer, power = 92.31%, pthr = 0.0501, delay 1.9798 days
# 18_Stouffer, power = 77.12%, pthr = 0.0485, delay 0.8316 days
# 19_Stouffer, power = 77.59%, pthr = 0.0478, delay 2.4579 days
# 20_Stouffer, power = 47.79%, pthr = 0.0500, delay 9.6734 days
# 21_Stouffer, power = 37.20%, pthr = 0.0500, delay 16.7104 days
# 22_Stouffer, power = 29.91%, pthr = 0.0377, delay 22.7374 days
# 23_Stouffer, power = 16.23%, pthr = 0.0595, delay 33.6364 days
# 24_Stouffer, power = 11.67%, pthr = 0.0355, delay 30.8182 days
# 25_Stouffer, power = 35.78%, pthr = 0.0500, delay 10.6128 days
# 26_Stouffer, power = 29.98%, pthr = 0.0486, delay 14.9226 days
# 27_Stouffer, power = 92.31%, pthr = 0.0501, delay 1.9798 days
# 28_Stouffer, power = 77.12%, pthr = 0.0485, delay 0.8316 days
# 29_Stouffer, power = 77.59%, pthr = 0.0478, delay 2.4579 days
# 30_Stouffer, power = 47.79%, pthr = 0.0500, delay 9.6734 days
# 31_Stouffer, power = 37.20%, pthr = 0.0500, delay 16.7104 days
# 32_Stouffer, power = 29.91%, pthr = 0.0377, delay 22.7374 days
# 33_Stouffer, power = 16.23%, pthr = 0.0595, delay 33.6364 days
# 34_Stouffer, power = 11.67%, pthr = 0.0355, delay 30.8182 days
# 35_Stouffer, power = 10.72%, pthr = 0.0450, delay 30.5993 days
# 36_Stouffer, power = 35.78%, pthr = 0.0500, delay 10.6128 days
# 37_Stouffer, power = 24.91%, pthr = 0.0500, delay 17.9495 days
# 38_Stouffer, power = 29.98%, pthr = 0.0486, delay 14.9226 days
# 0_Stolerman, power = 96.01%, cnt_thr = 1.00, delay 0.3771 days
# 1_Stolerman, power = 56.46%, cnt_thr = 3.00, delay 5.7441 days
# 2_Stolerman, power = 17.45%, cnt_thr = 3.00, delay 29.9663 days
# 3_Stolerman, power = 86.38%, cnt_thr = 5.00, delay 1.2862 days
# 4_Stolerman, power = 70.30%, cnt_thr = 7.00, delay 3.4848 days
# 5_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 6_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 7_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 8_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 9_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 10_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 11_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 12_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 13_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 14_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 15_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 16_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 17_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 18_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 19_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 20_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 21_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 22_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 23_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 24_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 25_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 26_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 27_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 28_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 29_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 30_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 31_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 32_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 33_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 34_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 35_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 36_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 37_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 38_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# Window size 19
# CPRadmission, power = 94.66%, pthr = 0.0500, delay 1.6195 days
# JHUcase, power = 77.45%, pthr = 0.0486, delay 0.7643 days
# CHNGclaim, power = 83.67%, pthr = 0.0477, delay 2.1279 days
# doctorvisits, power = 51.71%, pthr = 0.0500, delay 9.0303 days
# FBwtested, power = 41.42%, pthr = 0.0500, delay 15.7003 days
# FBwhh, power = 34.02%, pthr = 0.0361, delay 22.2222 days
# FBpositive, power = 18.07%, pthr = 0.0560, delay 33.6835 days
# QUIDELpositive, power = 12.93%, pthr = 0.0343, delay 29.8519 days
# FBwcli, power = 11.72%, pthr = 0.0440, delay 31.7003 days
# GoogleS03, power = 37.49%, pthr = 0.0500, delay 10.4141 days
# GoogleS04, power = 23.35%, pthr = 0.0500, delay 17.2323 days
# GoogleS05, power = 35.59%, pthr = 0.0489, delay 13.4680 days
# 0_Stouffer, power = 98.07%, pthr = 0.1234, delay 0.1953 days
# 1_Stouffer, power = 71.29%, pthr = 0.1592, delay 4.3704 days
# 2_Stouffer, power = 31.32%, pthr = 0.1564, delay 13.8923 days
# 3_Stouffer, power = 94.80%, pthr = 0.1961, delay 0.4579 days
# 4_Stouffer, power = 92.19%, pthr = 0.2093, delay 0.6061 days
# 5_Stouffer, power = 93.91%, pthr = 0.0501, delay 1.8620 days
# 6_Stouffer, power = 77.40%, pthr = 0.0487, delay 0.7643 days
# 7_Stouffer, power = 83.68%, pthr = 0.0477, delay 2.1279 days
# 8_Stouffer, power = 51.71%, pthr = 0.0500, delay 9.0303 days
# 9_Stouffer, power = 37.49%, pthr = 0.0500, delay 10.4141 days
# 10_Stouffer, power = 41.01%, pthr = 0.0500, delay 15.6869 days
# 11_Stouffer, power = 34.04%, pthr = 0.0364, delay 22.0842 days
# 12_Stouffer, power = 35.60%, pthr = 0.0489, delay 13.4579 days
# 13_Stouffer, power = 18.12%, pthr = 0.0567, delay 33.4848 days
# 14_Stouffer, power = 12.98%, pthr = 0.0345, delay 29.6902 days
# 15_Stouffer, power = 11.73%, pthr = 0.0441, delay 31.7003 days
# 16_Stouffer, power = 22.18%, pthr = 0.0500, delay 17.2323 days
# 17_Stouffer, power = 93.91%, pthr = 0.0501, delay 1.8620 days
# 18_Stouffer, power = 77.40%, pthr = 0.0487, delay 0.7643 days
# 19_Stouffer, power = 83.68%, pthr = 0.0477, delay 2.1279 days
# 20_Stouffer, power = 51.71%, pthr = 0.0500, delay 9.0303 days
# 21_Stouffer, power = 41.01%, pthr = 0.0500, delay 15.6869 days
# 22_Stouffer, power = 34.04%, pthr = 0.0364, delay 22.0842 days
# 23_Stouffer, power = 18.12%, pthr = 0.0567, delay 33.4848 days
# 24_Stouffer, power = 12.98%, pthr = 0.0345, delay 29.6902 days
# 25_Stouffer, power = 37.49%, pthr = 0.0500, delay 10.4141 days
# 26_Stouffer, power = 35.60%, pthr = 0.0489, delay 13.4579 days
# 27_Stouffer, power = 93.91%, pthr = 0.0501, delay 1.8620 days
# 28_Stouffer, power = 77.40%, pthr = 0.0487, delay 0.7643 days
# 29_Stouffer, power = 83.68%, pthr = 0.0477, delay 2.1279 days
# 30_Stouffer, power = 51.71%, pthr = 0.0500, delay 9.0303 days
# 31_Stouffer, power = 41.01%, pthr = 0.0500, delay 15.6869 days
# 32_Stouffer, power = 34.04%, pthr = 0.0364, delay 22.0842 days
# 33_Stouffer, power = 18.12%, pthr = 0.0567, delay 33.4848 days
# 34_Stouffer, power = 12.98%, pthr = 0.0345, delay 29.6902 days
# 35_Stouffer, power = 11.73%, pthr = 0.0441, delay 31.7003 days
# 36_Stouffer, power = 37.49%, pthr = 0.0500, delay 10.4141 days
# 37_Stouffer, power = 22.18%, pthr = 0.0500, delay 17.2323 days
# 38_Stouffer, power = 35.60%, pthr = 0.0489, delay 13.4579 days
# 0_Stolerman, power = 96.74%, cnt_thr = 1.00, delay 0.3266 days
# 1_Stolerman, power = 59.31%, cnt_thr = 3.00, delay 5.4512 days
# 2_Stolerman, power = 18.85%, cnt_thr = 3.00, delay 28.6061 days
# 3_Stolerman, power = 87.69%, cnt_thr = 5.00, delay 1.1279 days
# 4_Stolerman, power = 85.19%, cnt_thr = 6.00, delay 1.3064 days
# 5_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 6_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 7_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 8_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 9_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 10_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 11_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 12_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 13_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 14_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 15_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 16_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 17_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 18_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 19_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 20_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 21_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 22_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 23_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 24_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 25_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 26_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 27_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 28_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 29_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 30_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 31_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 32_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 33_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 34_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 35_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 36_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 37_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 38_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# Window size 21
# CPRadmission, power = 95.87%, pthr = 0.0500, delay 1.4882 days
# JHUcase, power = 76.61%, pthr = 0.0496, delay 0.9731 days
# CHNGclaim, power = 87.49%, pthr = 0.0478, delay 1.9596 days
# doctorvisits, power = 55.90%, pthr = 0.0500, delay 7.8283 days
# FBwtested, power = 45.60%, pthr = 0.0500, delay 15.7778 days
# FBwhh, power = 37.53%, pthr = 0.0341, delay 21.4714 days
# FBpositive, power = 20.01%, pthr = 0.0542, delay 32.9428 days
# QUIDELpositive, power = 14.40%, pthr = 0.0339, delay 28.7340 days
# FBwcli, power = 12.86%, pthr = 0.0435, delay 32.4882 days
# GoogleS03, power = 39.60%, pthr = 0.0500, delay 10.8350 days
# GoogleS04, power = 23.43%, pthr = 0.0500, delay 17.9495 days
# GoogleS05, power = 39.37%, pthr = 0.0490, delay 12.3670 days
# 0_Stouffer, power = 98.40%, pthr = 0.1206, delay 0.1684 days
# 1_Stouffer, power = 74.84%, pthr = 0.1542, delay 3.7340 days
# 2_Stouffer, power = 33.42%, pthr = 0.1521, delay 13.1414 days
# 3_Stouffer, power = 95.48%, pthr = 0.1873, delay 0.3704 days
# 4_Stouffer, power = 92.93%, pthr = 0.2010, delay 0.5455 days
# 5_Stouffer, power = 95.21%, pthr = 0.0501, delay 1.7441 days
# 6_Stouffer, power = 76.54%, pthr = 0.0496, delay 0.9731 days
# 7_Stouffer, power = 87.49%, pthr = 0.0479, delay 1.9596 days
# 8_Stouffer, power = 55.90%, pthr = 0.0500, delay 7.8283 days
# 9_Stouffer, power = 39.59%, pthr = 0.0500, delay 10.8283 days
# 10_Stouffer, power = 44.14%, pthr = 0.0500, delay 15.7845 days
# 11_Stouffer, power = 37.55%, pthr = 0.0343, delay 21.4714 days
# 12_Stouffer, power = 39.34%, pthr = 0.0491, delay 12.3670 days
# 13_Stouffer, power = 19.95%, pthr = 0.0543, delay 32.9461 days
# 14_Stouffer, power = 14.40%, pthr = 0.0341, delay 28.7340 days
# 15_Stouffer, power = 12.87%, pthr = 0.0436, delay 32.4175 days
# 16_Stouffer, power = 22.48%, pthr = 0.0500, delay 17.9495 days
# 17_Stouffer, power = 95.21%, pthr = 0.0501, delay 1.7441 days
# 18_Stouffer, power = 76.54%, pthr = 0.0496, delay 0.9731 days
# 19_Stouffer, power = 87.49%, pthr = 0.0479, delay 1.9596 days
# 20_Stouffer, power = 55.90%, pthr = 0.0500, delay 7.8283 days
# 21_Stouffer, power = 44.14%, pthr = 0.0500, delay 15.7845 days
# 22_Stouffer, power = 37.55%, pthr = 0.0343, delay 21.4714 days
# 23_Stouffer, power = 19.95%, pthr = 0.0543, delay 32.9461 days
# 24_Stouffer, power = 14.40%, pthr = 0.0341, delay 28.7340 days
# 25_Stouffer, power = 39.59%, pthr = 0.0500, delay 10.8283 days
# 26_Stouffer, power = 39.34%, pthr = 0.0491, delay 12.3670 days
# 27_Stouffer, power = 95.21%, pthr = 0.0501, delay 1.7441 days
# 28_Stouffer, power = 76.54%, pthr = 0.0496, delay 0.9731 days
# 29_Stouffer, power = 87.49%, pthr = 0.0479, delay 1.9596 days
# 30_Stouffer, power = 55.90%, pthr = 0.0500, delay 7.8283 days
# ...
# 4_Stouffer, power = 98.04%, pthr = 0.1521, delay 0.0707 days
# 5_Stouffer, power = 97.59%, pthr = 0.0501, delay 2.0404 days
# 6_Stouffer, power = 94.76%, pthr = 0.0503, delay 0.3165 days
# 7_Stouffer, power = 97.53%, pthr = 0.0473, delay 0.7643 days
# 8_Stouffer, power = 84.69%, pthr = 0.0500, delay 3.6599 days
# 9_Stouffer, power = 48.46%, pthr = 0.0500, delay 10.6397 days
# 10_Stouffer, power = 63.46%, pthr = 0.0500, delay 13.5320 days
# 11_Stouffer, power = 57.46%, pthr = 0.0212, delay 20.6296 days
# 12_Stouffer, power = 62.45%, pthr = 0.0494, delay 7.7912 days
# 13_Stouffer, power = 34.15%, pthr = 0.0410, delay 30.4848 days
# 14_Stouffer, power = 27.09%, pthr = 0.0271, delay 25.3232 days
# 15_Stouffer, power = 21.16%, pthr = 0.0301, delay 31.3502 days
# 16_Stouffer, power = 27.06%, pthr = 0.0500, delay 25.1414 days
# 17_Stouffer, power = 97.59%, pthr = 0.0501, delay 2.0404 days
# 18_Stouffer, power = 94.76%, pthr = 0.0503, delay 0.3165 days
# 19_Stouffer, power = 97.53%, pthr = 0.0473, delay 0.7643 days
# 20_Stouffer, power = 84.69%, pthr = 0.0500, delay 3.6599 days
# 21_Stouffer, power = 63.46%, pthr = 0.0500, delay 13.5320 days
# 22_Stouffer, power = 57.46%, pthr = 0.0212, delay 20.6296 days
# 23_Stouffer, power = 34.15%, pthr = 0.0410, delay 30.4848 days
# 24_Stouffer, power = 27.09%, pthr = 0.0271, delay 25.3232 days
# 25_Stouffer, power = 48.46%, pthr = 0.0500, delay 10.6397 days
# 26_Stouffer, power = 62.45%, pthr = 0.0494, delay 7.7912 days
# 27_Stouffer, power = 97.59%, pthr = 0.0501, delay 2.0404 days
# 28_Stouffer, power = 94.76%, pthr = 0.0503, delay 0.3165 days
# 29_Stouffer, power = 97.53%, pthr = 0.0473, delay 0.7643 days
# 30_Stouffer, power = 84.69%, pthr = 0.0500, delay 3.6599 days
# 31_Stouffer, power = 63.46%, pthr = 0.0500, delay 13.5320 days
# 32_Stouffer, power = 57.46%, pthr = 0.0212, delay 20.6296 days
# 33_Stouffer, power = 34.15%, pthr = 0.0410, delay 30.4848 days
# 34_Stouffer, power = 27.09%, pthr = 0.0271, delay 25.3232 days
# 35_Stouffer, power = 21.16%, pthr = 0.0301, delay 31.3502 days
# 36_Stouffer, power = 48.46%, pthr = 0.0500, delay 10.6397 days
# 37_Stouffer, power = 27.06%, pthr = 0.0500, delay 25.1414 days
# 38_Stouffer, power = 62.45%, pthr = 0.0494, delay 7.7912 days
# 0_Stolerman, power = 98.97%, cnt_thr = 1.00, delay 0.2727 days
# 1_Stolerman, power = 78.59%, cnt_thr = 3.00, delay 3.9461 days
# 2_Stolerman, power = 30.90%, cnt_thr = 3.00, delay 26.4209 days
# 3_Stolerman, power = 98.25%, cnt_thr = 4.00, delay 0.2121 days
# 4_Stolerman, power = 94.29%, cnt_thr = 6.00, delay 0.6700 days
# 5_Stolerman, power = 97.31%, cnt_thr = 0.00, delay 1.2761 days
# 6_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 7_Stolerman, power = 95.80%, cnt_thr = 0.00, delay 1.1515 days
# 8_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 9_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 10_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 11_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 12_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 13_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 14_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 15_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 16_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 17_Stolerman, power = 97.31%, cnt_thr = 0.00, delay 1.2761 days
# 18_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 19_Stolerman, power = 95.80%, cnt_thr = 0.00, delay 1.1515 days
# 20_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 21_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 22_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 23_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 24_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 25_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 26_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 27_Stolerman, power = 97.31%, cnt_thr = 0.00, delay 1.2761 days
# 28_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 29_Stolerman, power = 95.80%, cnt_thr = 0.00, delay 1.1515 days
# 30_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 31_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 32_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 33_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 34_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 35_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 36_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 37_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 38_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# Window size 43
# CPRadmission, power = 98.58%, pthr = 0.0500, delay 0.6936 days
# JHUcase, power = 95.29%, pthr = 0.0496, delay 0.2896 days
# CHNGclaim, power = 97.91%, pthr = 0.0474, delay 0.6498 days
# doctorvisits, power = 87.31%, pthr = 0.0500, delay 3.0943 days
# FBwtested, power = 71.82%, pthr = 0.0500, delay 12.9966 days
# FBwhh, power = 58.18%, pthr = 0.0200, delay 20.5455 days
# FBpositive, power = 35.87%, pthr = 0.0398, delay 30.1582 days
# QUIDELpositive, power = 28.12%, pthr = 0.0269, delay 25.3636 days
# FBwcli, power = 22.19%, pthr = 0.0301, delay 31.2862 days
# GoogleS03, power = 53.28%, pthr = 0.0500, delay 9.9394 days
# GoogleS04, power = 30.84%, pthr = 0.0500, delay 26.0673 days
# GoogleS05, power = 64.50%, pthr = 0.0493, delay 7.6162 days
# 0_Stouffer, power = 99.84%, pthr = 0.0902, delay 0.0067 days
# 1_Stouffer, power = 92.45%, pthr = 0.1168, delay 1.1448 days
# 2_Stouffer, power = 53.51%, pthr = 0.1190, delay 12.7811 days
# 3_Stouffer, power = 99.20%, pthr = 0.1412, delay 0.0202 days
# 4_Stouffer, power = 98.27%, pthr = 0.1495, delay 0.0471 days
# 5_Stouffer, power = 97.80%, pthr = 0.0501, delay 1.8990 days
# 6_Stouffer, power = 95.19%, pthr = 0.0497, delay 0.2896 days
# 7_Stouffer, power = 97.47%, pthr = 0.0475, delay 0.8114 days
# 8_Stouffer, power = 85.78%, pthr = 0.0500, delay 3.4377 days
# 9_Stouffer, power = 49.42%, pthr = 0.0500, delay 10.3333 days
# 10_Stouffer, power = 64.88%, pthr = 0.0500, delay 13.1616 days
# 11_Stouffer, power = 58.34%, pthr = 0.0204, delay 20.3636 days
# 12_Stouffer, power = 63.18%, pthr = 0.0493, delay 7.8418 days
# 13_Stouffer, power = 35.09%, pthr = 0.0400, delay 30.1684 days
# 14_Stouffer, power = 28.42%, pthr = 0.0272, delay 24.8586 days
# 15_Stouffer, power = 22.11%, pthr = 0.0302, delay 31.2862 days
# 16_Stouffer, power = 27.47%, pthr = 0.0500, delay 26.1044 days
# 17_Stouffer, power = 97.80%, pthr = 0.0501, delay 1.8990 days
# 18_Stouffer, power = 95.19%, pthr = 0.0497, delay 0.2896 days
# 19_Stouffer, power = 97.47%, pthr = 0.0475, delay 0.8114 days
# 20_Stouffer, power = 85.78%, pthr = 0.0500, delay 3.4377 days
# 21_Stouffer, power = 64.88%, pthr = 0.0500, delay 13.1616 days
# 22_Stouffer, power = 58.34%, pthr = 0.0204, delay 20.3636 days
# 23_Stouffer, power = 35.09%, pthr = 0.0400, delay 30.1684 days
# 24_Stouffer, power = 28.42%, pthr = 0.0272, delay 24.8586 days
# 25_Stouffer, power = 49.42%, pthr = 0.0500, delay 10.3333 days
# 26_Stouffer, power = 63.18%, pthr = 0.0493, delay 7.8418 days
# 27_Stouffer, power = 97.80%, pthr = 0.0501, delay 1.8990 days
# 28_Stouffer, power = 95.19%, pthr = 0.0497, delay 0.2896 days
# 29_Stouffer, power = 97.47%, pthr = 0.0475, delay 0.8114 days
# 30_Stouffer, power = 85.78%, pthr = 0.0500, delay 3.4377 days
# 31_Stouffer, power = 64.88%, pthr = 0.0500, delay 13.1616 days
# 32_Stouffer, power = 58.34%, pthr = 0.0204, delay 20.3636 days
# 33_Stouffer, power = 35.09%, pthr = 0.0400, delay 30.1684 days
# 34_Stouffer, power = 28.42%, pthr = 0.0272, delay 24.8586 days
# 35_Stouffer, power = 22.11%, pthr = 0.0302, delay 31.2862 days
# 36_Stouffer, power = 49.42%, pthr = 0.0500, delay 10.3333 days
# 37_Stouffer, power = 27.47%, pthr = 0.0500, delay 26.1044 days
# 38_Stouffer, power = 63.18%, pthr = 0.0493, delay 7.8418 days
# 0_Stolerman, power = 99.05%, cnt_thr = 1.00, delay 0.2525 days
# 1_Stolerman, power = 79.28%, cnt_thr = 3.00, delay 3.6667 days
# 2_Stolerman, power = 31.24%, cnt_thr = 3.00, delay 27.0337 days
# 3_Stolerman, power = 98.44%, cnt_thr = 4.00, delay 0.1953 days
# 4_Stolerman, power = 94.58%, cnt_thr = 6.00, delay 0.7306 days
# 5_Stolerman, power = 97.36%, cnt_thr = 0.00, delay 1.2256 days
# 6_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 7_Stolerman, power = 96.02%, cnt_thr = 0.00, delay 1.1717 days
# 8_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 9_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 10_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 11_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 12_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 13_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 14_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 15_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 16_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 17_Stolerman, power = 97.36%, cnt_thr = 0.00, delay 1.2256 days
# 18_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 19_Stolerman, power = 96.02%, cnt_thr = 0.00, delay 1.1717 days
# 20_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 21_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 22_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 23_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 24_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 25_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 26_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 27_Stolerman, power = 97.36%, cnt_thr = 0.00, delay 1.2256 days
# 28_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 29_Stolerman, power = 96.02%, cnt_thr = 0.00, delay 1.1717 days
# 30_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 31_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 32_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 33_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 34_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 35_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 36_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 37_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 38_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# Window size 45
# CPRadmission, power = 98.73%, pthr = 0.0500, delay 0.6128 days
# JHUcase, power = 96.13%, pthr = 0.0489, delay 0.2862 days
# CHNGclaim, power = 98.08%, pthr = 0.0476, delay 0.6532 days
# doctorvisits, power = 88.33%, pthr = 0.0500, delay 2.8653 days
# FBwtested, power = 72.66%, pthr = 0.0500, delay 12.8822 days
# FBwhh, power = 59.14%, pthr = 0.0199, delay 20.4209 days
# FBpositive, power = 36.73%, pthr = 0.0390, delay 30.0505 days
# QUIDELpositive, power = 29.69%, pthr = 0.0264, delay 25.0101 days
# FBwcli, power = 23.33%, pthr = 0.0287, delay 30.7407 days
# GoogleS03, power = 53.97%, pthr = 0.0500, delay 10.3131 days
# GoogleS04, power = 30.86%, pthr = 0.0500, delay 29.2761 days
# GoogleS05, power = 66.13%, pthr = 0.0490, delay 7.4983 days
# 0_Stouffer, power = 99.86%, pthr = 0.0892, delay 0.0034 days
# 1_Stouffer, power = 92.94%, pthr = 0.1156, delay 1.0741 days
# 2_Stouffer, power = 55.51%, pthr = 0.1185, delay 12.3603 days
# 3_Stouffer, power = 99.30%, pthr = 0.1395, delay 0.0101 days
# 4_Stouffer, power = 98.39%, pthr = 0.1473, delay 0.0404 days
# 5_Stouffer, power = 98.03%, pthr = 0.0501, delay 1.8384 days
# 6_Stouffer, power = 96.02%, pthr = 0.0490, delay 0.3502 days
# 7_Stouffer, power = 97.37%, pthr = 0.0477, delay 1.1582 days
# 8_Stouffer, power = 86.32%, pthr = 0.0500, delay 3.3872 days
# 9_Stouffer, power = 49.92%, pthr = 0.0500, delay 10.6902 days
# 10_Stouffer, power = 65.80%, pthr = 0.0500, delay 13.0471 days
# 11_Stouffer, power = 59.15%, pthr = 0.0202, delay 20.4141 days
# 12_Stouffer, power = 64.59%, pthr = 0.0491, delay 7.7340 days
# 13_Stouffer, power = 35.73%, pthr = 0.0392, delay 29.9697 days
# 14_Stouffer, power = 30.00%, pthr = 0.0270, delay 24.7138 days
# 15_Stouffer, power = 23.26%, pthr = 0.0288, delay 30.7374 days
# 16_Stouffer, power = 26.58%, pthr = 0.0500, delay 29.3199 days
# 17_Stouffer, power = 98.03%, pthr = 0.0501, delay 1.8384 days
# 18_Stouffer, power = 96.02%, pthr = 0.0490, delay 0.3502 days
# 19_Stouffer, power = 97.37%, pthr = 0.0477, delay 1.1582 days
# 20_Stouffer, power = 86.32%, pthr = 0.0500, delay 3.3872 days
# 21_Stouffer, power = 65.80%, pthr = 0.0500, delay 13.0471 days
# 22_Stouffer, power = 59.15%, pthr = 0.0202, delay 20.4141 days
# 23_Stouffer, power = 35.73%, pthr = 0.0392, delay 29.9697 days
# 24_Stouffer, power = 30.00%, pthr = 0.0270, delay 24.7138 days
# 25_Stouffer, power = 49.92%, pthr = 0.0500, delay 10.6902 days
# 26_Stouffer, power = 64.59%, pthr = 0.0491, delay 7.7340 days
# 27_Stouffer, power = 98.03%, pthr = 0.0501, delay 1.8384 days
# 28_Stouffer, power = 96.02%, pthr = 0.0490, delay 0.3502 days
# 29_Stouffer, power = 97.37%, pthr = 0.0477, delay 1.1582 days
# 30_Stouffer, power = 86.32%, pthr = 0.0500, delay 3.3872 days
# 31_Stouffer, power = 65.80%, pthr = 0.0500, delay 13.0471 days
# 32_Stouffer, power = 59.15%, pthr = 0.0202, delay 20.4141 days
# 33_Stouffer, power = 35.73%, pthr = 0.0392, delay 29.9697 days
# 34_Stouffer, power = 30.00%, pthr = 0.0270, delay 24.7138 days
# 35_Stouffer, power = 23.26%, pthr = 0.0288, delay 30.7374 days
# 36_Stouffer, power = 49.92%, pthr = 0.0500, delay 10.6902 days
# 37_Stouffer, power = 26.58%, pthr = 0.0500, delay 29.3199 days
# 38_Stouffer, power = 64.59%, pthr = 0.0491, delay 7.7340 days
# 0_Stolerman, power = 99.10%, cnt_thr = 1.00, delay 0.2256 days
# 1_Stolerman, power = 80.39%, cnt_thr = 3.00, delay 3.4007 days
# 2_Stolerman, power = 32.36%, cnt_thr = 3.00, delay 26.1145 days
# 3_Stolerman, power = 98.58%, cnt_thr = 4.00, delay 0.1852 days
# 4_Stolerman, power = 94.96%, cnt_thr = 6.00, delay 0.5825 days
# 5_Stolerman, power = 97.45%, cnt_thr = 0.00, delay 1.1684 days
# 6_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 7_Stolerman, power = 96.20%, cnt_thr = 0.00, delay 1.1111 days
# 8_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 9_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 10_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 11_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 12_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 13_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 14_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 15_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 16_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 17_Stolerman, power = 97.45%, cnt_thr = 0.00, delay 1.1684 days
# 18_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 19_Stolerman, power = 96.20%, cnt_thr = 0.00, delay 1.1111 days
# 20_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 21_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 22_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 23_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 24_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 25_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 26_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 27_Stolerman, power = 97.45%, cnt_thr = 0.00, delay 1.1684 days
# 28_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 29_Stolerman, power = 96.20%, cnt_thr = 0.00, delay 1.1111 days
# 30_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 31_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 32_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 33_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 34_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 35_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 36_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 37_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
# 38_Stolerman, power = 0.00%, cnt_thr = 1.00, delay 60.0000 days
